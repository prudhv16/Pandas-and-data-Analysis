# %%
import numpy as np
import pandas as pd
from pandas import DataFrame,Series

# %%
import webbrowser
website = 'https://en.wikipedia.org/wiki/NFL_win-loss_records'
webbrowser.open(website)
# Out:
# True

# %%
nfl_frame = pd.read_clipboard()

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
nfl_frame.columns
# Out:
# Index([u'Rank', u'Team', u'Won', u'Lost', u'Tied', u'Pct.', u'First', u'NFL',
#        u'Season', u'Total', u'Games', u'Division'],
#       dtype='object')

# %%
nfl_frame['Games']
# Out:
# 0    North
# 1     East
# 2      NFC
# 3     East
# 4      AFC
# Name: Games, dtype: object

# %%
DataFrame(nfl_frame,columns=['Team','Tied','Games','Stadium'])
# Out:
#       Team  Tied  Games  Stadium
# 0  Chicago   555  North      NaN
# 1   Dallas   364   East      NaN
# 2    Green   720    NFC      NaN
# 3    Miami   335   East      NaN
# 4      New   462    AFC      NaN

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
nfl_frame.head(3)
# Out:
#    Rank     Team      Won     Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago    Bears      741   555    42   0.570  1920.000  1,338
# 1     2   Dallas  Cowboys      480   364     6   0.568  1960.000    850
# 2     3    Green      Bay  Packers   720   547  37.000     0.566   1921
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North

# %%
nfl_frame.tail(2)
# Out:
#    Rank   Team       Won      Lost  Tied  Pct.  First       NFL Season Total  \
# 3     4  Miami  Dolphins       429   335     4  0.561  1966.000    768   AFC
# 4     5    New   England  Patriots   462   381  9.000     0.548   1960   852
#
#   Games Division
# 3  East      NaN
# 4   AFC     East

# %%
nfl_frame.ix[3]
# Out:
# Rank               4
# Team           Miami
# Won         Dolphins
# Lost             429
# Tied             335
# Pct.               4
# First          0.561
# NFL             1966
# Season           768
# Total            AFC
# Games           East
# Division         NaN
# Name: 3, dtype: object

# %%
nfl_frame['Stadium'] = "Levi's Stadium"

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division         Stadium
# 0    NFC  North      NaN  Levi's Stadium
# 1    NFC   East      NaN  Levi's Stadium
# 2  1,304    NFC    North  Levi's Stadium
# 3    AFC   East      NaN  Levi's Stadium
# 4    852    AFC     East  Levi's Stadium

# %%
nfl_frame['Stadium'] = np.arange(5)

# %%
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division  Stadium
# 0    NFC  North      NaN        0
# 1    NFC   East      NaN        1
# 2  1,304    NFC    North        2
# 3    AFC   East      NaN        3
# 4    852    AFC     East        4

# %%
Stadium = Series(['Levi\'s Stadium','AT&T Stadium'],index =[4,0])
Stadium
# Out:
# 4    Levi's Stadium
# 0      AT&T Stadium
# dtype: object

# %%
nfl_frame['Stadium'] = Stadium
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division         Stadium
# 0    NFC  North      NaN    AT&T Stadium
# 1    NFC   East      NaN             NaN
# 2  1,304    NFC    North             NaN
# 3    AFC   East      NaN             NaN
# 4    852    AFC     East  Levi's Stadium

# %%
del nfl_frame['Stadium']
nfl_frame
# Out:
#    Rank     Team       Won      Lost  Tied  Pct.   First       NFL Season  \
# 0     1  Chicago     Bears       741   555    42   0.570  1920.000  1,338
# 1     2   Dallas   Cowboys       480   364     6   0.568  1960.000    850
# 2     3    Green       Bay   Packers   720   547  37.000     0.566   1921
# 3     4    Miami  Dolphins       429   335     4   0.561  1966.000    768
# 4     5      New   England  Patriots   462   381   9.000     0.548   1960
#
#    Total  Games Division
# 0    NFC  North      NaN
# 1    NFC   East      NaN
# 2  1,304    NFC    North
# 3    AFC   East      NaN
# 4    852    AFC     East

# %%
data = {'City':['SF','LA','NYC'],'Population':[837000,3880000,8400000]}

# %%
city_frame = DataFrame(data)
city_frame
# Out:
#   City  Population
# 0   SF      837000
# 1   LA     3880000
# 2  NYC     8400000
