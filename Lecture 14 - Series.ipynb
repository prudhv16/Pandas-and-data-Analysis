# %%
import numpy as np
import pandas as pd
from pandas import Series,DataFrame

# %%
obj = Series([3,6,9,12])
obj
# Out:
# 0     3
# 1     6
# 2     9
# 3    12
# dtype: int64

# %%
obj.values
# Out:
# array([ 3,  6,  9, 12], dtype=int64)

# %%
obj.index
# Out:
# Int64Index([0, 1, 2, 3], dtype='int64')

# %%
ww2_cas = Series([8700000,4300000,3000000,2100000,400000],index=['USSR','Germany','China','Japan','USA'])
ww2_cas
# Out:
# USSR       8700000
# Germany    4300000
# China      3000000
# Japan      2100000
# USA         400000
# dtype: int64

# %%
ww2_cas['USA']
# Out:
# 400000

# %%
#Check array operations
ww2_cas[ww2_cas>4000000]
# Out:
# USSR       8700000
# Germany    4300000
# dtype: int64

# %%
'USSR' in ww2_cas
# Out:
# True

# %%
ww2_dict = ww2_cas.to_dict()
ww2_dict
# Out:
# {'China': 3000000,
#  'Germany': 4300000,
#  'Japan': 2100000,
#  'USA': 400000,
#  'USSR': 8700000}

# %%
ww2_series = Series(ww2_dict)
ww2_series
# Out:
# China      3000000
# Germany    4300000
# Japan      2100000
# USA         400000
# USSR       8700000
# dtype: int64

# %%
countries = ['China','Germany','Japan','USA','USSR','Argentina']

# %%
obj2 = Series(ww2_dict,index=countries)

# %%
obj2
# Out:
# China        3000000
# Germany      4300000
# Japan        2100000
# USA           400000
# USSR         8700000
# Argentina        NaN
# dtype: float64

# %%
pd.isnull(obj2)
# Out:
# China        False
# Germany      False
# Japan        False
# USA          False
# USSR         False
# Argentina     True
# dtype: bool

# %%
pd.notnull(obj2)
# Out:
# China         True
# Germany       True
# Japan         True
# USA           True
# USSR          True
# Argentina    False
# dtype: bool

# %%
ww2_series + obj2
# Out:
# Argentina         NaN
# China         6000000
# Germany       8600000
# Japan         4200000
# USA            800000
# USSR         17400000
# dtype: float64

# %%
obj2.name = 'World war 2 casulaities'
obj2
# Out:
# China        3000000
# Germany      4300000
# Japan        2100000
# USA           400000
# USSR         8700000
# Argentina        NaN
# Name: World war 2 casulaities, dtype: float64

# %%
obj2.index.name = 'Countires'
obj2
# Out:
# Countires
# China        3000000
# Germany      4300000
# Japan        2100000
# USA           400000
# USSR         8700000
# Argentina        NaN
# Name: World war 2 casulaities, dtype: float64
